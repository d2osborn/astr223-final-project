# %% [markdown]
# # ASTR 223 Final Project: GP Projections

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pybaseball.statcast as pyb

# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

from data_manager import get_statcast_data

# %%
df = get_statcast_data(start_date='2025-03-01', end_date='2025-11-01', filename='files/statcast_2025.parquet')
df.head()
# Out:
# This is a large query, it may take a moment to complete
# Skipping offseason dates
#  10%|█         | 24/232 [00:46<03:51,  1.11s/it]

# %%
df
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 598          CH 2024-10-01           88.1          -1.65           6.12
# 625          CH 2024-10-01           87.1          -1.69           6.17
# 647          CH 2024-10-01           89.7          -1.89           6.14
# 676          FF 2024-10-01           97.5          -1.51           6.32
# 702          CH 2024-10-01           88.6          -1.77           6.19
# ...         ...        ...            ...            ...            ...
# 3658         FF 2024-04-01           97.5           1.77           5.84
# 3768         FF 2024-04-01           98.6           2.02           5.88
# 3890         FF 2024-04-01           97.7           2.05           5.83
# 4009         FF 2024-04-01           96.8            2.1           5.84
# 4130         FF 2024-04-01           97.3           2.14           5.78
#
#           player_name  batter  pitcher     events      description  ...  \
# ...
